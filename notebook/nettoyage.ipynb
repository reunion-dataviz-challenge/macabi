# %%
import pandas as pd

# %%
path_lit = "C:/Users/Idriss K/Desktop/DataViz/data/POPMER/reefdb-extraction-complet-POPMER_LIT-2023-10-20-081836.csv"
data_lit = pd.read_csv(path_lit, sep=";")
# Out:
# C:\Users\Idriss K\AppData\Local\Temp\ipykernel_22168\563788912.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_lit = pd.read_csv(path_lit, sep=";")

# %%
data_lit.head()
# Out:
#                       Programme          Station        Date  REPLICAT_Numero  \
# 0  POPMER_LAREUNION_LIT_BENTHOS  L'Ermitage_GH09  31/12/2008                1
# 1  POPMER_LAREUNION_LIT_BENTHOS  L'Ermitage_GH09  31/12/2008                1
# 2  POPMER_LAREUNION_LIT_BENTHOS  L'Ermitage_GH09  31/12/2008                1
# 3  POPMER_LAREUNION_LIT_BENTHOS  L'Ermitage_GH09  31/12/2008                1
# 4  POPMER_LAREUNION_LIT_BENTHOS  L'Ermitage_GH09  31/12/2008                1
#
#    Taxon            Groupe_taxons  MESURE_Numero_individu  \
# 0    NaN                      NaN                       1
# 1    NaN          Acropore digité                       2
# 2    NaN  Non-Acropore encroutant                       3
# 3    NaN                      NaN                       4
# 4    NaN         Acropore branchu                       5
#
#    REPLICAT_Transition_Protocole_LIT-Centimetre  \
# 0                                           150
# ...

# %%
print(len(list(data_lit.columns)))
print(list(data_lit.columns))
# Out:
# 79
# ...

# %%
keep_columns = ["Station","Date","Taxon", "Groupe_taxons", "MESURE_Numero_individu", 
                "REPLICAT_Longueur_transect_metre_ruban-Metre",
                "STATION_Identifiant","OBSERVATION_Coordonnees_MINX","OBSERVATION_Coordonnees_MINY", 
                "OBSERVATION_Coordonnees_MAXX", "OBSERVATION_Coordonnees_MAXY",
                "REPLICAT_Substrat_Protocole_LIT"]
cleaned_data = data_lit[keep_columns]

# %%
cleaned_data.head()
# Out:
#            Station        Date  Taxon            Groupe_taxons  \
# 0  L'Ermitage_GH09  31/12/2008    NaN                      NaN
# 1  L'Ermitage_GH09  31/12/2008    NaN          Acropore digité
# 2  L'Ermitage_GH09  31/12/2008    NaN  Non-Acropore encroutant
# 3  L'Ermitage_GH09  31/12/2008    NaN                      NaN
# 4  L'Ermitage_GH09  31/12/2008    NaN         Acropore branchu
#
#    MESURE_Numero_individu REPLICAT_Longueur_transect_metre_ruban-Metre  \
# 0                       1                                         2000
# 1                       2                                         2000
# 2                       3                                         2000
# 3                       4                                         2000
# 4                       5                                         2000
#
#    STATION_Identifiant OBSERVATION_Coordonnees_MINX  \
# 0             60010458                     55,22161
# ...

# %%
cleaned_data.shape
# Out:
# (31769, 12)

# %% [markdown]
# # Flag

# %%
cleaned_data["Flag"] = "substrat"
# Out:
# C:\Users\Idriss K\AppData\Local\Temp\ipykernel_22168\1378411534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data["Flag"] = "substrat"

# %%
cleaned_data.head()
# Out:
#            Station        Date  Taxon            Groupe_taxons  \
# 0  L'Ermitage_GH09  31/12/2008    NaN                      NaN
# 1  L'Ermitage_GH09  31/12/2008    NaN          Acropore digité
# 2  L'Ermitage_GH09  31/12/2008    NaN  Non-Acropore encroutant
# 3  L'Ermitage_GH09  31/12/2008    NaN                      NaN
# 4  L'Ermitage_GH09  31/12/2008    NaN         Acropore branchu
#
#    MESURE_Numero_individu REPLICAT_Longueur_transect_metre_ruban-Metre  \
# 0                       1                                         2000
# 1                       2                                         2000
# 2                       3                                         2000
# 3                       4                                         2000
# 4                       5                                         2000
#
#    STATION_Identifiant OBSERVATION_Coordonnees_MINX  \
# 0             60010458                     55,22161
# ...

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31769 entries, 0 to 31768
# Data columns (total 13 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Station                                       31769 non-null  object
#  1   Date                                          31769 non-null  object
#  2   Taxon                                         0 non-null      float64
#  3   Groupe_taxons                                 25870 non-null  object
#  4   MESURE_Numero_individu                        31769 non-null  int64
#  5   REPLICAT_Longueur_transect_metre_ruban-Metre  31769 non-null  object
#  6   STATION_Identifiant                           31769 non-null  int64
#  7   OBSERVATION_Coordonnees_MINX                  31769 non-null  object
#  8   OBSERVATION_Coordonnees_MINY                  31769 non-null  object
# ...

# %%
unique_station = cleaned_data["STATION_Identifiant"].unique()

# %%
print(len(unique_station))
print(unique_station)
# Out:
# 90
# [60010458 60010459 60010460 60010461 60010462 60010463 60010464 60010465
#  60010466 60010469 60010470 60010471 60010472 60010473 60010474 60010475
#  60010476 60010477 60010478 60010479 60010530 60010531 60010532 60010533
#  60010534 60010535 60010536 60010537 60010538 60010539 60010450 60010451
#  60010452 60010453 60010454 60010455 60010456 60010457 60010480 60010481
#  60010482 60010483 60010484 60010485 60010486 60010487 60010488 60010489
#  60010467 60010468 60010490 60010491 60010492 60010493 60010494 60010495
#  60010496 60010497 60010498 60010499 60010500 60010501 60010502 60010503
#  60010504 60010505 60010506 60010507 60010508 60010509 60010510 60010511
#  60010512 60010513 60010514 60010515 60010516 60010517 60010518 60010519
#  60010520 60010521 60010522 60010523 60010524 60010525 60010526 60010527
#  60010528 60010529]

# %%
cleaned_data.rename(columns={"REPLICAT_Longueur_transect_metre_ruban-Metre":"REPLICAT_Longueur_transect"}, inplace=True)
# Out:
# C:\Users\Idriss K\AppData\Local\Temp\ipykernel_22168\1400430952.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data.rename(columns={"REPLICAT_Longueur_transect_metre_ruban-Metre":"REPLICAT_Longueur_transect"}, inplace=True)

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31769 entries, 0 to 31768
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Station                          31769 non-null  object
#  1   Date                             31769 non-null  object
#  2   Taxon                            0 non-null      float64
#  3   Groupe_taxons                    25870 non-null  object
#  4   MESURE_Numero_individu           31769 non-null  int64
#  5   REPLICAT_Longueur_transect       31769 non-null  object
#  6   STATION_Identifiant              31769 non-null  int64
#  7   OBSERVATION_Coordonnees_MINX     31769 non-null  object
#  8   OBSERVATION_Coordonnees_MINY     31769 non-null  object
#  9   OBSERVATION_Coordonnees_MAXX     31769 non-null  object
#  10  OBSERVATION_Coordonnees_MAXY     31769 non-null  object
#  11  REPLICAT_Substrat_Protocole_LIT  26416 non-null  object
# ...

# %%
col_rep = ["OBSERVATION_Coordonnees_MINX", "OBSERVATION_Coordonnees_MINY", 
           "OBSERVATION_Coordonnees_MAXX", "OBSERVATION_Coordonnees_MAXY"]
cleaned_data[col_rep] = cleaned_data[col_rep].replace(',', '.', regex=True)
# Out:
# C:\Users\Idriss K\AppData\Local\Temp\ipykernel_22168\2739511040.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data[col_rep] = cleaned_data[col_rep].replace(',', '.', regex=True)

# %%
date_format = pd.to_datetime(cleaned_data['Date'], format="%d/%m/%Y")
cleaned_data["Year"] = date_format.dt.year
cleaned_data["Date"] = date_format
# Out:
# C:\Users\Idriss K\AppData\Local\Temp\ipykernel_22168\49110650.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data["Year"] = date_format.dt.year
# C:\Users\Idriss K\AppData\Local\Temp\ipykernel_22168\49110650.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data["Date"] = date_format

# %%
cleaned_data.to_csv("../data/lit_cleadedAndTransform.csv", sep=",",  index=False)

# %%
cleaned_data.head()
# Out:
#            Station       Date  Taxon            Groupe_taxons  \
# 0  L'Ermitage_GH09 2008-12-31    NaN                      NaN
# 1  L'Ermitage_GH09 2008-12-31    NaN          Acropore digité
# 2  L'Ermitage_GH09 2008-12-31    NaN  Non-Acropore encroutant
# 3  L'Ermitage_GH09 2008-12-31    NaN                      NaN
# 4  L'Ermitage_GH09 2008-12-31    NaN         Acropore branchu
#
#    MESURE_Numero_individu REPLICAT_Longueur_transect  STATION_Identifiant  \
# 0                       1                       2000             60010458
# 1                       2                       2000             60010458
# 2                       3                       2000             60010458
# 3                       4                       2000             60010458
# 4                       5                       2000             60010458
#
#   OBSERVATION_Coordonnees_MINX OBSERVATION_Coordonnees_MINY  \
# 0                     55.22161                    -21.08205
# ...
